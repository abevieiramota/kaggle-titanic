# %%
import pandas as pd
import lxml

# %%
df = pd.read_html(open('/home/abelardo/Desktop/teste.html'))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-b35e324f10c7> in <module>()
# ----> 1 df = pd.read_html(open('/home/abelardo/Desktop/teste.html'))
#
# /home/abelardo/Documents/SCI/local/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, infer_types, attrs, parse_dates, tupleize_cols, thousands)
#     837                          'data (you passed a negative value)')
#     838     return _parse(flavor, io, match, header, index_col, skiprows, infer_types,
# --> 839                   parse_dates, tupleize_cols, thousands, attrs)
#
# /home/abelardo/Documents/SCI/local/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, infer_types, parse_dates, tupleize_cols, thousands, attrs)
#     696     retained = None
#     697     for flav in flavor:
# ...

# %%
df
# Out:
#    Nome    Lotação Cargo   Remu. Paradigma Vant. Pessoais  Subsídio, FC e CJ   Indeniz.    Vant. Eventuais Total de Créditos   Prev. Pública   Imposto Renda   Descontos Diversos  Retenção Teto Const.    Total Débitos   Rend. Líquido   Remun. Origem   Diárias
# 0   Adaíres Aguiar Lima EFETIVO REMOVIDO    Técnic...
# 1   Adeilson Batista Mendes SEÇÃO DE PROTOCOLO E A...
# 2   Admir Castro Dos Santos DIRETORIA-GERAL Técnic...
# 3   Adriana Avelino Meneses COORDENADORIA DE DESEN...
# 4   Adriano Lima De Sousa   SEÇÃO DE LICITAÇÕES E ...
# 5   Adson Cardoso Monteiro  COORDENADORIA DE SOLUÇ...
# 6   Agostino Silvério Junior    TRIBUNAL REGIONAL ...
# 7   Ailton Marcelo Mota Vidal   TRIBUNAL REGIONAL ...
# 8   Alderico Pinto E Silva  COORDENADORIA DE DESEN...
# 9   Alessandro Heric Nunes Gurgel   SEÇÃO DE TRANS...
# 10  Alessandro Rilsoney Dias De Souza   ASSESSORIA...
# 11  Alexandre Flávio Medeiros Monteiro  8ª ZE. TAR...
# 12  Alexandro Dourado De Aragão GABINETE DA DIRETO...
# ...
