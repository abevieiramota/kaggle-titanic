# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("../data/train_final.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare     ...       \
# 0      0         A/5 21171   7.2500     ...
# 1      0          PC 17599  71.2833     ...
# 2      0  STON/O2. 3101282   7.9250     ...
# 3      0            113803  53.1000     ...
# 4      0            373450   8.0500     ...
#
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'hasTitle',
#        'FamilyName', 'Title', 'FirstName', 'TitleClass', 'FamilySize',
#        'AgeClassDesc', 'AgeClass', 'SexClass', 'EmbarkedClass',
#        'pctFamilySurvived', 'nFamilySurvived', 'nFamilyDied'],
#       dtype='object')

# %%
df.sort_values(["FamilySize", "FamilyName"], ascending=False)[["Name", "FamilyName", "Cabin", "pctFamilySurvived"]]
# Out:
#                                                   Name    FamilyName Cabin  \
# 745                         Sage, Master. Thomas Henry          Sage   NaN
# 749                       Sage, Miss. Constance Gladys          Sage   NaN
# 755                                Sage, Mr. Frederick          Sage   NaN
# 777                           Sage, Mr. George John Jr          Sage   NaN
# 875                            Sage, Miss. Stella Anna          Sage   NaN
# 884                           Sage, Mr. Douglas Bullen          Sage   NaN
# 887                  Sage, Miss. Dorothy Edith "Dolly"          Sage   NaN
# 44                  Goodwin, Master. William Frederick       Goodwin   NaN
# 54                          Goodwin, Miss. Lillian Amy       Goodwin   NaN
# 309                    Goodwin, Master. Sidney Leonard       Goodwin   NaN
# 383                     Goodwin, Master. Harold Victor       Goodwin   NaN
# ...

# %%
df[df.FamilyName.isin(df[~df.Cabin.isnull()]["FamilyName"])].sort_values(["FamilyName"], ascending=False)[["Name", "FamilyName", "Cabin", "Survived", "Age", "Pclass", "Embarked"]]
# Out:
#                                                   Name  \
# 261                           Young, Miss. Marie Grice
# 728                                  Woolner, Mr. Hugh
# 782             Williams-Lambert, Mr. Fletcher Fellows
# 301                          Widener, Mr. Harry Elkins
# 255                           Wick, Miss. Mary Natalie
# 684         Wick, Mrs. George Dennick (Mary Hitchcock)
# 98                         White, Mr. Percival Wayland
# 79                           White, Mr. Richard Frasar
# 97                                 Webber, Miss. Susan
# 818                                  Webber, Mr. James
# 293   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 410                       Walker, Mr. William Anderson
# 136                          Van der hoef, Mr. Wyckoff
# 570                Troutt, Miss. Edwina Celia "Winnie"
# 871                                   Tobin, Mr. Roger
# 437                        Thayer, Mr. John Borland Jr
# ...

# %%
df.groupby(["Embarked", "Survived"]).size()
# Out:
# Embarked  Survived
# C         0            75
#           1            93
# Q         0            47
#           1            30
# S         0           427
#           1           219
# dtype: int64
